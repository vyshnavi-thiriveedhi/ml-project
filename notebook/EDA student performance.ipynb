# %% [markdown]
# ### importing all the libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### importing the csv file

# %%
df = pd.read_csv("data/stud.csv")

# %% [markdown]
# ### checking the top 5 data

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ### finding rows and columns

# %%
df.shape
# Out:
# (1000, 8)

# %% [markdown]
# ### finding the number of null values in each column

# %%
df.isnull().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %% [markdown]
# ### checking if they are duplicated data

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### checking the datatypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# ### checking no of unique values in each column

# %%
df.nunique()
# Out:
# gender                          2
# race_ethnicity                  5
# parental_level_of_education     6
# lunch                           2
# test_preparation_course         2
# math_score                     81
# reading_score                  72
# writing_score                  77
# dtype: int64

# %% [markdown]
# ### check statistics

# %%
df.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ## finding the unique values in all the columns

# %%
print("number of unique values in the gender column is {0} and they are: {1}".format(df.gender.nunique(),df.gender.unique()))

print("number of unique values in the race_ethnicity column is {0} and they are: {1}".format(df.race_ethnicity.nunique(),df.race_ethnicity.unique()))

print("number of unique values in the parental_level_of_education column is {0} and they are: {1}".format(df.parental_level_of_education.nunique(),df.parental_level_of_education.unique()))

print("number of unique values in the lunch column is {0} and they are: {1}".format(df.lunch.nunique(),df.lunch.unique()))

print("number of unique values in the test_preparation_course column is {0} and they are: {1}".format(df.test_preparation_course.nunique(),df.test_preparation_course.unique()))

print("number of unique values in the math_score column is {0} and they are: {1}".format(df.math_score.nunique(),df.math_score.unique()))

print("number of unique values in the reading_score column is {0} and they are: {1}".format(df.reading_score.nunique(),df.reading_score.unique()))

print("number of unique values in the writing_score column is {0} and they are: {1}".format(df.writing_score.nunique(),df.writing_score.unique()))
# Out:
# number of unique values in the gender column is 2 and they are: ['female' 'male']
# number of unique values in the race_ethnicity column is 5 and they are: ['group B' 'group C' 'group A' 'group D' 'group E']
# number of unique values in the parental_level_of_education column is 6 and they are: ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
# number of unique values in the lunch column is 2 and they are: ['standard' 'free/reduced']
# number of unique values in the test_preparation_course column is 2 and they are: ['none' 'completed']
# number of unique values in the math_score column is 81 and they are: [ 72  69  90  47  76  71  88  40  64  38  58  65  78  50  18  46  54  66
#   44  74  73  67  70  62  63  56  97  81  75  57  55  53  59  82  77  33
#   52   0  79  39  45  60  61  41  49  30  80  42  27  43  68  85  98  87
#   51  99  84  91  83  89  22 100  96  94  48  35  34  86  92  37  28  24
# ...

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# ## defining numerical and categorical columns

# %%
categorical_features=[feature for feature in df.columns if df[feature].dtype=='O']
numerical_features=[feature for feature in df.columns if df[feature].dtype!='O']
print(f"the number of categorical features are:{len(categorical_features)} and they are {categorical_features}")
print(f"the number of numerical features are:{len(numerical_features)} and they are {numerical_features}")
# Out:
# the number of categorical features are:5 and they are ['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch', 'test_preparation_course']
# the number of numerical features are:3 and they are ['math_score', 'reading_score', 'writing_score']

# %%
print(len(df.columns))
# Out:
# 8

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ### finding total_score and average

# %%
df['total_score']=df['math_score']+df['reading_score']+df['writing_score']
df['average']=df['total_score']/3
print(df['total_score'])
print(df['average'])
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
#       ...
# 995    282
# 996    172
# 997    195
# 998    223
# 999    249
# Name: total_score, Length: 1000, dtype: int64
# 0      72.666667
# 1      82.333333
# 2      92.666667
# 3      49.333333
# 4      76.333333
#          ...
# 995    94.000000
# 996    57.333333
# 997    65.000000
# 998    74.333333
# 999    83.000000
# Name: average, Length: 1000, dtype: float64

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score    average
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %% [markdown]
# ### finding people with full scores

# %%
reading_score_full=df[df['reading_score']==100]['average'].count()
writing_score_full=df[df['writing_score']==100]['average'].count()
math_score_full=df[df['math_score']==100]['average'].count()

print(f"number of students with full score in maths is {math_score_full}")
print(f"number of students with full score in writing is {writing_score_full}")
print(f"number of students with full score in reading is {reading_score_full}")
# Out:
# number of students with full score in maths is 7
# number of students with full score in writing is 14
# number of students with full score in reading is 17

# %% [markdown]
# ## students  scored with less than 20

# %%
reading_score_less=df[df['reading_score']<20]['average'].count()
writing_score_less=df[df['writing_score']<20]['average'].count()
math_score_less=df[df['math_score']<20]['average'].count()

print(f"number of students with less score in maths is {math_score_less}")
print(f"number of students with less score in writing is {writing_score_less}")
print(f"number of students with less score in reading is {reading_score_less}")
# Out:
# number of students with less score in maths is 4
# number of students with less score in writing is 3
# number of students with less score in reading is 1

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score    average
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %% [markdown]
# ### Data visualization

# %%
sns.histplot(data=df,x='average',bins=30,kde=True,color='g')
# Out:
# <Axes: xlabel='average', ylabel='Count'>

# %%
sns.histplot(data=df,x='average',kde=True,hue='gender')
# Out:
# <Axes: xlabel='average', ylabel='Count'>

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 7))
plt.subplot(121)
sns.histplot(data=df,x='total_score',bins=30,kde=True,color='g')
plt.subplot(122)
sns.histplot(data=df,x='total_score',kde=True,hue='gender')
plt.show()

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df,x='average',kde=True,hue='lunch')
plt.subplot(142)
sns.histplot(data=df[df.gender=='female'],x='average',kde=True,hue='lunch')
plt.subplot(143)
sns.histplot(data=df[df.gender=='male'],x='average',kde=True,hue='lunch')
plt.show()

# %% [markdown]
# ### max score of students in all thre subjects

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score    average
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %%
plt.figure(figsize=(18,8))
plt.subplot(1, 4, 1)
plt.title("MATH SCORES")
sns.violinplot(y='math_score',data=df,color='red',linewidth=3)
plt.subplot(1, 4, 2)
plt.title('READING SCORES')
sns.violinplot(y='reading_score',data=df,color='green',linewidth=3)
plt.subplot(1, 4, 3)    
plt.title('WRITING SCORES')
sns.violinplot(y='writing_score',data=df,color='blue',linewidth=3)
plt.show()
